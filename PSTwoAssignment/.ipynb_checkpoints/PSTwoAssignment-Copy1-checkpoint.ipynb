# %% [markdown]
# # Question 1
# Consider the following Python module:
# a = 0
# def b():
# global a
# a = c(a)
# def c(a):
# return a + 2
# After importing the module into the interpreter, you execute:
# >>> b()
# >>> b()
# >>> b()
# >>> a
# ?
# What value is displayed when the last expression (a) is evaluated? Explain your answer by indicating what happens in every executed statement.

# %%
a = 0
def b():
    global a
    a = c(a)
def c(a):
    return a + 2
b()
b()
b()
a
# Out:
# 6

# %% [markdown]
# # Answer:
# a is initially assigned as 0, the variable belongs to the global scope. The function b is called thrice. Each time b() is called 2 is added to a, hence when called thrice 2 is added 3 times.

# %% [markdown]
# # Question 2
# Function fileLength(), given to you, takes the name of a file as input and returns the length of the file:
# >>> fileLength('midterm.py')
# 284
# >>> fileLength('idterm.py')
# Traceback (most recent call last):
#     File "<pyshell#34>", line 1, in <module>
#         fileLength('idterm.py')
#     File "/Users/me/midterm.py", line 3, in fileLength
#         infile = open(filename)
# FileNotFoundError: [Errno 2] No such file or directory:
# 'idterm.py'
#
# As shown above, if the file cannot be found by the interpreter or if it cannot be read as a text file, an exception will be raised. Modify function fileLength() so that a friendly message is printed instead:
# >>> fileLength('midterm.py')
# 358
# >>> fileLength('idterm.py')
# File idterm.py not found.

# %%
def fileLength(filename):
    try:
        file = open(filename)
        contents = file.read()
        file.close()
        print(len(contents))
    except FileNotFoundError: #handle error
        print(f"File {filename} not found.")
    except:
        print("An error occurred while reading the file.")

fileLength('midterm.py') 
fileLength('idterm.py')
# Out:
# 55
# File idterm.py not found.

# %% [markdown]
# # Question 3
# Write a class named Marsupial that can be used as shown below:
# >>> m = Marsupial()
# >>> m.put_in_pouch('doll')
# >>> m.put_in_pouch('firetruck')
# >>> m.put_in_pouch('kitten')
# >>> m.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the attributes of Marsupial and also:
# a. extends the Marsupial __init__ constructor to take, as input, the coordinates x and y of the Kangaroo object,
# b. supports method jump that takes number values dx and dy as input and moves the kangaroo by dx units along the x-axis and by dy units along the y-axis, and
# c. overloads the __str__ operator so it behaves as shown below.
# >>> k = Kangaroo(0,0)
# >>> print(k) I am a Kangaroo located at coordinates (0,0)
# >>> k.put_in_pouch('doll')
# >>> k.put_in_pouch('firetruck')
# >>> k.put_in_pouch('kitten')
# >>> k.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >> k.jump(1,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (3,0)

# %%
class Marsupial:#define class
    def __init__(self):
        self.pouchList = [] #initialize an empty list

    # method adds value to the list    
    def put_in_pouch(self, inputVal):
        self.pouchList.append(inputVal)

    # method returns list of items   
    def pouch_contents(self):
        return self.pouchList
        
m = Marsupial()
m.put_in_pouch('doll')
m.put_in_pouch('firetruck')
m.put_in_pouch('kitten')
m.pouch_contents()
# Out:
# ['doll', 'firetruck', 'kitten']

# %%
class Marsupial:
    def __init__(self):
        self.pouchList = []

    def put_in_pouch(self, inputVal):
        self.pouchList.append(inputVal)

    def pouch_contents(self):
        print(self.pouchList)


class Kangaroo(Marsupial):#extend class Marsupial
    def __init__(self,x,y):
        super().__init__()#access parent constructor
        self.x1 = x
        self.y1 = y

    #method to increment coordinates    
    def jump(self,x,y):
        self.x1=self.x1+x
        self.y1=self.y1+y

    #override __str__
    def __str__(self):
        return f"I am Kangaroo located at coordinates {self.x1},{self.y1}"

k = Kangaroo(0,0)
print(k)
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
k.pouch_contents()
k.jump(1,0)
k.jump(1,0)
k.jump(1,0)
print(k)
# Out:
# I am Kangaroo located at coordinates 0,0
# ['doll', 'firetruck', 'kitten']
# I am Kangaroo located at coordinates 3,0

# %% [markdown]
# # Question 4
# Write function collatz() that takes a positive integer x as input and prints the Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying this rule to the previous number x in the sequence:
# x = { 𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛, 3𝑥+1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑
# Your function should stop when the sequence gets to number 1. Your implementation must be recursive, without any loops.
# >>> collatz(1)
# 1
# >>> collatz(10)
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
def collatz(x): 
        
        if x!=1:
            print(int(x))
            if x%2 == 0: #check even
                x = x/2
            else:       #odd
                x = (3*x)+1
            collatz(x)
        else:
            print(int(x))

while True:  
    x = int(input("Enter input(Press 0 to Exit): "))
    if x == 0:
        break
    elif x<=0:  
        print("Invalid input! Enter positive integer.")
    else:
        collatz(x)
# Out:
# Enter input(Press 0 to Exit): 11
# 11
# 34
# 17
# 52
# 26
# 13
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# 1
# Enter input(Press 0 to Exit): 10
# 10
# 5
# 16
# 8
# 4
# 2
# 1
# Enter input(Press 0 to Exit): 1
# 1
# Enter input(Press 0 to Exit): 0

# %% [markdown]
# # Question 5
# Write a recursive method binary() that takes a non-negative integer n and prints the binary representation of integer n.
# >>> binary(0)
# 0
# >>> binary(1)
# 1
# >>> binary(3)
# 11
# >>> binary(9)
# 1001

# %%
def binary(Input):
    if Input>0:
        binaryVal = Input%2  #find remainder
        print(binaryVal, end ='')
        Input = int(Input/2) #find quotient
        binary(Input) #recursive method call
while True:  
    Input = input("\nEnter input(Press # to Exit): ")
    if Input == '#':
        break
    elif int(Input)<0:  
        print("\nInvalid input! Enter positive integer.")
    elif Input ==0:
        print(0)
    else:
        binary(int(Input))
# Out:
# Enter input(Press # to Exit): 0
#
# Enter input(Press # to Exit): 1
# 1
# Enter input(Press # to Exit): 3
# 11
# Enter input(Press # to Exit): 9
# 1001
# Enter input(Press # to Exit): 11
# 1101
# Enter input(Press # to Exit): #

# %% [markdown]
# # Question 8
# Write SQL queries on the below database table that return:

# %% [markdown]
# ![qs8ps2.png](attachment:qs8ps2.png)

# %%
import sqlite3
con = sqlite3.connect('Weather1.db') #create connection to database
cur = con.cursor() #create database cursor
cur.execute("CREATE TABLE Weather1tab (City, Country, Season, Temperature, Rainfall)") #create table

# %%
infile = open("Seasons.csv", "r")
line = infile.readlines() #read input file
infile.close()
line.pop(0) #exclude column names
for row in line:
    #print(row.split(","))
    col=row.split(",")
    print(col)
    #Insert values into the table
    cur.execute("INSERT INTO Weather1tab VALUES (?, ?, ?, ?, ?)", (col[0], col[1], col[2], float(col[3]), float(col[4].strip())))
# Out:
# ['Mumbai', 'India', 'Winter', '24.8', '5.9\n']
# ['Mumbai', 'India', 'Spring', '28.4', '16.2\n']
# ['Mumbai', 'India', 'Summer', '27.9', '1549.4\n']
# ['Mumbai', 'India', 'Fall', '27.6', '346.0\n']
# ['London', 'United Kingdom', 'Winter', '4.2', '207.7\n']
# ['London', 'United Kingdom', 'Spring', '8.3', '169.6\n']
# ['London', 'United Kingdom', 'Summer', '15.7', '157.0\n']
# ['London', 'United Kingdom', 'Fall', '10.4', '218.5\n']
# ['Cairo', 'Egypt', 'Winter', '13.6', '16.5\n']
# ['Cairo', 'Egypt', 'Spring', '20.7', '6.5\n']
# ['Cairo', 'Egypt', 'Summer', '27.7', '0.1\n']
# ['Cairo', 'Egypt', 'Fall', '22.2', '4.5\n']

# %%
cur.execute('SELECT * FROM Weather1tab')
#display all values in table
for record in cur:
    print(record)
# Out:
# ('Mumbai', 'India', 'Winter', 24.8, 5.9)
# ('Mumbai', 'India', 'Spring', 28.4, 16.2)
# ('Mumbai', 'India', 'Summer', 27.9, 1549.4)
# ('Mumbai', 'India', 'Fall', 27.6, 346.0)
# ('London', 'United Kingdom', 'Winter', 4.2, 207.7)
# ('London', 'United Kingdom', 'Spring', 8.3, 169.6)
# ('London', 'United Kingdom', 'Summer', 15.7, 157.0)
# ('London', 'United Kingdom', 'Fall', 10.4, 218.5)
# ('Cairo', 'Egypt', 'Winter', 13.6, 16.5)
# ('Cairo', 'Egypt', 'Spring', 20.7, 6.5)
# ('Cairo', 'Egypt', 'Summer', 27.7, 0.1)
# ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)

# %% [markdown]
# # a)
# All the temperature data.

# %%
cur.execute('SELECT Temperature FROM Weather1tab')

for record in cur:
    print(record)
# Out:
# (24.8,)
# (28.4,)
# (27.9,)
# (27.6,)
# (4.2,)
# (8.3,)
# (15.7,)
# (10.4,)
# (13.6,)
# (20.7,)
# (27.7,)
# (22.2,)

# %% [markdown]
# # b)
# All the cities, but without repetition.

# %%
cur.execute('SELECT DISTINCT(City) FROM Weather1tab')

for record in cur:
    print(record)
# Out:
# ('Mumbai',)
# ('London',)
# ('Cairo',)

# %% [markdown]
# # c)
# All the records for India.

# %%
cur.execute('SELECT * FROM Weather1tab WHERE Country="India"')

for record in cur:
    print(record)
# Out:
# ('Mumbai', 'India', 'Winter', 24.8, 5.9)
# ('Mumbai', 'India', 'Spring', 28.4, 16.2)
# ('Mumbai', 'India', 'Summer', 27.9, 1549.4)
# ('Mumbai', 'India', 'Fall', 27.6, 346.0)

# %% [markdown]
# # d)
# All the Fall records.

# %%
cur.execute('SELECT * FROM Weather1tab WHERE Season="Fall"')

for record in cur:
    print(record)
# Out:
# ('Mumbai', 'India', 'Fall', 27.6, 346.0)
# ('London', 'United Kingdom', 'Fall', 10.4, 218.5)
# ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)

# %% [markdown]
# # e)
# The city, country, and season for which the average rainfall is between 200 and 400 millimeters.

# %%
cur.execute('SELECT City, Country, Season FROM Weather1tab GROUP BY City, Country, Season HAVING AVG(Rainfall) BETWEEN 200 AND 400')

for record in cur:
    print(record)
# Out:
# ('London', 'United Kingdom', 'Fall')
# ('London', 'United Kingdom', 'Winter')
# ('Mumbai', 'India', 'Fall')

# %% [markdown]
# # f)
# The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order.

# %%
cur.execute('SELECT City, Country FROM Weather1tab WHERE Season = "Fall" GROUP BY City, Country HAVING AVG(Temperature)>20 ORDER BY Temperature')

for record in cur:
    print(record)
# Out:
# ('Cairo', 'Egypt')
# ('Mumbai', 'India')

# %% [markdown]
# # g)
# The total annual rainfall for Cairo.

# %%
cur.execute('SELECT SUM(Rainfall) FROM Weather1tab WHERE City = "Cairo"')

for record in cur:
    print(record)
# Out:
# (27.6,)

# %% [markdown]
# # h)
# The total rainfall for each season.

# %%
cur.execute('SELECT Season, SUM(Rainfall) FROM Weather1tab GROUP BY Season')

for record in cur:
    print(record)
# Out:
# ('Fall', 569.0)
# ('Spring', 192.29999999999998)
# ('Summer', 1706.5)
# ('Winter', 230.1)

# %% [markdown]
# # Question 9
# Suppose list words is defined as follows:
# >>> words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# Write list comprehension expressions that use list words and generate the following lists:

# %% [markdown]
# # a)
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

words1 = [x.upper() for x in words] 

print(words1)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']

# %% [markdown]
# # b)
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

words2 = [x.lower() for x in words] 

print(words2)
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %% [markdown]
# # c)
# [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list words).

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

count = [len(x) for x in words]

print(count)
# Out:
# [3, 5, 5, 3, 5, 4, 3, 4, 3]

# %% [markdown]
# # d)
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list words, where each list contains the word in uppercase and lowercase and the length of the word.)

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

result = [[x.upper(), x.lower(), len(x)] for x in words]

print(result)
# Out:
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]

# %% [markdown]
# # e)
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog'] (the list of words in list words containing 4 or more characters.)

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

result = [ x for x in words if len(x)>=4]

print(result)
# Out:
# ['quick', 'brown', 'jumps', 'over', 'lazy']
